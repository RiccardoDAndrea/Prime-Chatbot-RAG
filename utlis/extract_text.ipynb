# %%
from pypdf import PdfReader
import os

reader = PdfReader("PDF_docs/doc_0.pdf")
page = reader.pages[1]
print(page)
parts = []


def visitor_body(text, cm, tm, font_dict, font_size):
    y = cm[5]
    if  560 < y < 756:
        parts.append(text)


text = page.extract_text(visitor_text=visitor_body)

print(text)
# Out:
# {'/Contents': [IndirectObject(30, 0, 139920330126288), IndirectObject(45, 0, 139920330126288), IndirectObject(31, 0, 139920330126288)], '/BleedBox': [0.0, 0.0, 567, 756], '/Type': '/Page', '/ArtBox': [0.0, 0.0, 567, 756], '/Resources': {'/ColorSpace': {'/CS0': IndirectObject(46, 0, 139920330126288)}, '/ExtGState': {'/GS1': IndirectObject(47, 0, 139920330126288), '/GS2': IndirectObject(48, 0, 139920330126288), '/GS0': IndirectObject(49, 0, 139920330126288)}, '/ProcSet': ['/PDF', '/Text', '/ImageB', '/ImageC', '/ImageI'], '/Font': {'/T1_0': IndirectObject(50, 0, 139920330126288), '/T1_2': IndirectObject(51, 0, 139920330126288), '/T1_1': IndirectObject(52, 0, 139920330126288), '/T1_8': IndirectObject(53, 0, 139920330126288), '/T1_7': IndirectObject(54, 0, 139920330126288), '/T1_4': IndirectObject(55, 0, 139920330126288), '/T1_3': IndirectObject(56, 0, 139920330126288), '/T1_6': IndirectObject(57, 0, 139920330126288), '/T1_5': IndirectObject(58, 0, 139920330126288)}, '/XObject': {'/Xi4':
# ...
